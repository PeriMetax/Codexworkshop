# %% [markdown]
# # Taxonomy Validator Workbook\nUse this workbook to test validation and correction logic quickly.

# %%
from app.services.validator import validate_taxonomy_string\nfrom app.services.correction import suggest_correction

# %%
mapping = {\n  'delimiter': '_',\n  'components': [\n    {'name':'channel','required':True,'allowed_values':['meta','google'],'aliases':{'facebook':'meta'}},\n    {'name':'market','required':True,'allowed_values':['us','uk'],'aliases':{'usa':'us'}},\n    {'name':'objective','required':True,'allowed_values':['awareness','conversion'],'aliases':{'conv':'conversion'}}\n  ]\n}\nresult = validate_taxonomy_string('facebook_usa_conversoin', mapping)\nsuggestion = suggest_correction(result.parsed, mapping)\nresult, suggestion
